# %% [markdown]
# # ws 08

# %% [markdown]
# - download -
# https://kaggle.com/ultralytics/coco128

# %% [markdown]
# # ws 09 , 10
# use ws 06

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 2.5.0+cpu (CPU)

# %%
#!python yolov5-master/train.py --data coco128.yaml --cfg yolov5s.yaml --weights yolov5s.pt --batch-size 32 --epochs 20

# %%
import torch
print(torch.cuda.is_available())  # Should return True if GPU is available
# Out:
# False

# %%
from IPython.display import Image
Image(filename='datasets/coco128/images/train2017/000000000034.jpg', width=600)
Image(filename='datasets/coco128/images/train2017/000000000036.jpg', width=600)
